# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulchowdary07/Weather-Prediction/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather=pd.read_csv("3723951.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    68  81.0   NaN
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    67  83.0   NaN
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  55.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2024-06-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN  75.0
# 2024-06-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.43    84  93.0  75.0
# 2024-06-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    86   NaN   NaN
# 2024-06-16  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    87  94.0  79.0
# 2024-06-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN   NaN
#
# [8924 rows x 6 columns]

# %%
# @title TAVG vs TMAX

from matplotlib import pyplot as plt
weather.plot(kind='scatter', x='TAVG', y='TMAX', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title TAVG

from matplotlib import pyplot as plt
weather['TAVG'].plot(kind='hist', bins=20, title='TAVG')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
weather["PRCP"].value_counts()
# Out:
# PRCP
# 0.00    1760
# 0.08     161
# 0.04     154
# 0.01     151
# 0.02     149
#         ...
# 3.78       1
# 0.26       1
# 2.68       1
# 4.80       1
# 2.48       1
# Name: count, Length: 98, dtype: int64

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.615083
# TAVG       0.000000
# TMAX       0.230278
# TMIN       0.351524
# dtype: float64

# %%
weather[pd.isnull(weather["PRCP"])]
# Out:
#                 STATION                      NAME  PRCP  TAVG   TMAX  TMIN
# DATE
# 2000-01-14  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    78   90.0  64.0
# 2000-01-15  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    76   91.0   NaN
# 2000-01-16  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    76   88.0  66.0
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    76    NaN   NaN
# 2000-01-18  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    74   90.0  61.0
# ...                 ...                       ...   ...   ...    ...   ...
# 2024-06-01  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    95  106.0  87.0
# 2024-06-02  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    89  104.0   NaN
# 2024-06-03  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    83  105.0  74.0
# 2024-06-04  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    85    NaN   NaN
# 2024-06-16  IN001080500  BEGUMPET OBSERVATORY, IN   NaN    87   94.0  79.0
#
# [5489 rows x 6 columns]

# %%
weather["PRCP"]=weather["PRCP"].fillna(0.00)

# %%
weather[pd.isnull(weather["TMAX"])]
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN
# DATE
# 2000-01-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    76   NaN   NaN
# 2000-02-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    75   NaN  62.0
# 2000-03-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    82   NaN  65.0
# 2000-03-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN  67.0
# 2000-04-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    89   NaN  78.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2024-06-10  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN  76.0
# 2024-06-12  IN001080500  BEGUMPET OBSERVATORY, IN  0.08    83   NaN  73.0
# 2024-06-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN  75.0
# 2024-06-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    86   NaN   NaN
# 2024-06-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83   NaN   NaN
#
# [2055 rows x 6 columns]

# %%
weather["TMAX"].value_counts()
# Out:
# TMAX
# 89.0     551
# 87.0     511
# 90.0     502
# 92.0     429
# 85.0     424
# 86.0     421
# 88.0     392
# 91.0     388
# 93.0     287
# 94.0     260
# 83.0     202
# 84.0     193
# 96.0     191
# 98.0     166
# 103.0    163
# 99.0     162
# 95.0     161
# 101.0    153
# 97.0     147
# 104.0    136
# 102.0    127
# 82.0     127
# 100.0    123
# 105.0    120
# 106.0     94
# 81.0      78
# 107.0     77
# 108.0     70
# 109.0     49
# 80.0      49
# 79.0      31
# 78.0      19
# 110.0     18
# 77.0      18
# 76.0      14
# 75.0       5
# 111.0      3
# 74.0       2
# 112.0      2
# 72.0       1
# 71.0       1
# 73.0       1
# 69.0       1
# Name: count, dtype: int64

# %%
weather=weather.fillna(method="ffill")

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.0
# NAME       0.0
# PRCP       0.0
# TAVG       0.0
# TMAX       0.0
# TMIN       0.0
# dtype: float64

# %%
weather.dtypes
# Out:
# STATION     object
# NAME        object
# PRCP       float64
# TAVG         int64
# TMAX       float64
# TMIN       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2024-06-08', '2024-06-09', '2024-06-10', '2024-06-11', '2024-06-12',
#        '2024-06-13', '2024-06-14', '2024-06-15', '2024-06-16', '2024-06-17'],
#       dtype='object', name='DATE', length=8924)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2024-06-08', '2024-06-09', '2024-06-10', '2024-06-11',
#                '2024-06-12', '2024-06-13', '2024-06-14', '2024-06-15',
#                '2024-06-16', '2024-06-17'],
#               dtype='datetime64[ns]', name='DATE', length=8924, freq=None)

# %%
weather["target_tmax"]=weather.shift(-1)["TMAX"]
weather["target_tmin"]=weather.shift(-1)["TMIN"]
weather["target_tavg"]=weather.shift(-1)["TAVG"]
weather["target_prp"]=weather.shift(-1)["PRCP"]
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    68  81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    67  83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  55.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2024-06-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83  93.0  75.0
# 2024-06-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.43    84  93.0  75.0
# 2024-06-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    86  93.0  75.0
# 2024-06-16  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    87  94.0  79.0
# 2024-06-17  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83  94.0  79.0
#
#             target_tmax  target_tmin  target_tavg  target_prp
# DATE
# 2000-01-01         81.0         60.0         68.0        0.00
# 2000-01-02         83.0         60.0         67.0        0.00
# 2000-01-03         83.0         53.0         69.0        0.00
# 2000-01-04         83.0         55.0         69.0        0.00
# 2000-01-05         83.0         54.0         69.0        0.00
# ...                 ...          ...          ...         ...
# 2024-06-13         93.0         75.0         84.0        0.43
# 2024-06-14         93.0         75.0         86.0        0.00
# 2024-06-15         94.0         79.0         87.0        0.00
# 2024-06-16         94.0         79.0         83.0        0.00
# 2024-06-17          NaN          NaN          NaN         NaN
#
# [8924 rows x 10 columns]

# %%
weather=weather.iloc[:-1:].copy()
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    68  81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    67  83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  55.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2024-06-12  IN001080500  BEGUMPET OBSERVATORY, IN  0.08    83  93.0  73.0
# 2024-06-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83  93.0  75.0
# 2024-06-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.43    84  93.0  75.0
# 2024-06-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    86  93.0  75.0
# 2024-06-16  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    87  94.0  79.0
#
#             target_tmax  target_tmin  target_tavg  target_prp
# DATE
# 2000-01-01         81.0         60.0         68.0        0.00
# 2000-01-02         83.0         60.0         67.0        0.00
# 2000-01-03         83.0         53.0         69.0        0.00
# 2000-01-04         83.0         55.0         69.0        0.00
# 2000-01-05         83.0         54.0         69.0        0.00
# ...                 ...          ...          ...         ...
# 2024-06-12         93.0         75.0         83.0        0.00
# 2024-06-13         93.0         75.0         84.0        0.43
# 2024-06-14         93.0         75.0         86.0        0.00
# 2024-06-15         94.0         79.0         87.0        0.00
# 2024-06-16         94.0         79.0         83.0        0.00
#
# [8923 rows x 10 columns]

# %%
weather["monthly_avg"]=weather["TAVG"].groupby(weather.index.month).apply(lambda  x:x.expanding(1).mean()).reset_index(level=0,drop=True)

# %%
weather["day_avg_of_yr"]=weather["TAVG"].groupby(weather.index.dayofyear).apply(lambda  x:x.expanding(1).mean()).reset_index(level=0,drop=True)
weather
# Out:
#                 STATION                      NAME  PRCP  TAVG  TMAX  TMIN  \
# DATE
# 2000-01-01  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    71  82.0  60.0
# 2000-01-02  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    68  81.0  60.0
# 2000-01-03  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    67  83.0  60.0
# 2000-01-04  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  53.0
# 2000-01-05  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    69  83.0  55.0
# ...                 ...                       ...   ...   ...   ...   ...
# 2024-06-12  IN001080500  BEGUMPET OBSERVATORY, IN  0.08    83  93.0  73.0
# 2024-06-13  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    83  93.0  75.0
# 2024-06-14  IN001080500  BEGUMPET OBSERVATORY, IN  0.43    84  93.0  75.0
# 2024-06-15  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    86  93.0  75.0
# 2024-06-16  IN001080500  BEGUMPET OBSERVATORY, IN  0.00    87  94.0  79.0
#
#             target_tmax  target_tmin  target_tavg  target_prp  monthly_avg  \
# DATE
# 2000-01-01         81.0         60.0         68.0        0.00    71.000000
# 2000-01-02         83.0         60.0         67.0        0.00    69.500000
# 2000-01-03         83.0         53.0         69.0        0.00    68.666667
# 2000-01-04         83.0         55.0         69.0        0.00    68.750000
# 2000-01-05         83.0         54.0         69.0        0.00    68.800000
# ...                 ...          ...          ...         ...          ...
# 2024-06-12         93.0         75.0         83.0        0.00    84.857923
# 2024-06-13         93.0         75.0         84.0        0.43    84.855389
# 2024-06-14         93.0         75.0         86.0        0.00    84.854223
# 2024-06-15         94.0         79.0         87.0        0.00    84.855782
# 2024-06-16         94.0         79.0         83.0        0.00    84.858696
#
#             day_avg_of_yr
# DATE
# 2000-01-01          71.00
# 2000-01-02          68.00
# 2000-01-03          67.00
# 2000-01-04          69.00
# 2000-01-05          69.00
# ...                   ...
# 2024-06-12          84.24
# 2024-06-13          83.68
# 2024-06-14          84.56
# 2024-06-15          84.72
# 2024-06-16          84.84
#
# [8923 rows x 12 columns]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers
import numpy as np

# %%
train_dataset = weather.sample(frac=0.6, random_state=0)
test_dataset = weather.drop(train_dataset.index)
cv_dataset=test_dataset.sample(frac=0.5,random_state=0)

# %%
x_train=np.array(train_dataset[["PRCP","TAVG","TMAX","TMIN","monthly_avg","day_avg_of_yr"]])
y_train=np.array(train_dataset[["target_tmax","target_tmin","target_tavg","target_prp"]])
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_cv=np.array(cv_dataset[["PRCP","TAVG","TMAX","TMIN","monthly_avg","day_avg_of_yr"]])
y_cv=np.array(cv_dataset[["target_tmax","target_tmin","target_tavg","target_prp"]])

# %%
x_train.shape
x_cv.shape
# Out:
# (1784, 6)

# %%
y_train.shape
y_cv.shape
# Out:
# (1784, 4)

# %%
model = Sequential([
    Dense(units=500,activation="relu",kernel_regularizer=regularizers.l2(0.1),input_shape=(6,)),
    Dense(units=200,activation="relu",kernel_regularizer=regularizers.l2(0.01)),
    Dense(units=100,activation="relu",kernel_regularizer=regularizers.l2(0.01)),
    Dense(units=40,activation="relu",kernel_regularizer=regularizers.l2(0.01)),
    Dense(units=4,activation="relu",kernel_regularizer=regularizers.l2(0.01)),
])

# %%
model.compile(loss='mean_squared_error',
                optimizer=tf.keras.optimizers.Adam(0.0005))

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 2s 5ms/step - loss: 1678.9891
# Epoch 2/100
# 168/168 [==============================] - 1s 5ms/step - loss: 65.6819
# Epoch 3/100
# 168/168 [==============================] - 1s 4ms/step - loss: 25.6027
# Epoch 4/100
# 168/168 [==============================] - 1s 4ms/step - loss: 14.8534
# Epoch 5/100
# 168/168 [==============================] - 1s 5ms/step - loss: 11.6753
# Epoch 6/100
# 168/168 [==============================] - 1s 5ms/step - loss: 10.6779
# Epoch 7/100
# 168/168 [==============================] - 1s 5ms/step - loss: 10.1328
# Epoch 8/100
# 168/168 [==============================] - 1s 4ms/step - loss: 9.7248
# Epoch 9/100
# 168/168 [==============================] - 1s 5ms/step - loss: 9.4561
# Epoch 10/100
# 168/168 [==============================] - 1s 5ms/step - loss: 9.2557
# Epoch 11/100
# 168/168 [==============================] - 1s 5ms/step - loss: 9.0775
# Epoch 12/100
# 168/168 [==============================] - 1s 5ms/step - loss: 8.9289
# Epoch 13/100
# 168/168 [==============================] - 1s 8ms/step - loss: 8.8090
# Epoch 14/100
# 168/168 [==============================] - 1s 8ms/step - loss: 8.6928
# Epoch 15/100
# 168/168 [==============================] - 1s 7ms/step - loss: 8.4218
# Epoch 16/100
# 168/168 [==============================] - 1s 5ms/step - loss: 8.2897
# Epoch 17/100
# 168/168 [==============================] - 1s 5ms/step - loss: 8.2018
# Epoch 18/100
# 168/168 [==============================] - 1s 5ms/step - loss: 8.0934
# Epoch 19/100
# 168/168 [==============================] - 1s 5ms/step - loss: 7.9662
# Epoch 20/100
# 168/168 [==============================] - 1s 5ms/step - loss: 7.9226
# Epoch 21/100
# 168/168 [==============================] - 1s 5ms/step - loss: 7.5840
# Epoch 22/100
# 168/168 [==============================] - 1s 5ms/step - loss: 5.1058

# %%
x_cv=scaler.transform(x_cv)
predictions = model.predict(x_cv)
predictions.shape
# Out:
# 56/56 [==============================] - 0s 2ms/step
# (1784, 4)

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error

# %%
y_cv.shape
# Out:
# (1784, 4)

# %%
mse = mean_squared_error(np.array(y_cv),np.array(predictions))
mse
# Out:
# 4.108885709381827

# %%
mse1=mean_squared_error(np.array(y_train),model.predict(x_train))
mse1
# Out:
# 168/168 [==============================] - 0s 2ms/step
# 4.060745614555444

# %%
x_test=np.array(test_dataset[["PRCP","TAVG","TMAX","TMIN","monthly_avg","day_avg_of_yr"]])
y_test=np.array(test_dataset[["target_tmax","target_tmin","target_tavg","target_prp"]])

# %%
y_test
# Out:
# array([[8.1e+01, 6.0e+01, 6.8e+01, 0.0e+00],
#        [8.3e+01, 5.3e+01, 6.9e+01, 0.0e+00],
#        [8.3e+01, 5.5e+01, 6.9e+01, 0.0e+00],
#        ...,
#        [9.3e+01, 7.3e+01, 8.3e+01, 8.0e-02],
#        [9.3e+01, 7.5e+01, 8.3e+01, 0.0e+00],
#        [9.3e+01, 7.5e+01, 8.6e+01, 0.0e+00]])

# %%
x_test=scaler.transform(x_test)
y_pred=model.predict(x_test)
y_pred
# Out:
# 112/112 [==============================] - 0s 2ms/step
# array([[82.964745, 60.586437, 71.26252 ,  0.      ],
#        [81.71855 , 58.948704, 68.33356 ,  0.      ],
#        [84.039566, 54.553818, 69.84436 ,  0.      ],
#        ...,
#        [91.90956 , 74.94091 , 80.54387 ,  0.      ],
#        [93.38144 , 74.15375 , 83.0205  ,  0.      ],
#        [93.33273 , 76.21477 , 83.825165,  0.      ]], dtype=float32)

# %%
mse2=mean_squared_error(np.array(y_test),y_pred)
mse2
# Out:
# 4.058405363820914

# %%
y_test_df=pd.DataFrame(y_test)
y_test_df.columns=["target_tmax","target_tmin","target_tavg","target_prp"]
y_test_df
combined =pd.concat([y_test_df,pd.DataFrame(y_pred)],axis=1)
combined
# Out:
#       target_tmax  target_tmin  target_tavg  target_prp          0          1  \
# 0            81.0         60.0         68.0        0.00  82.964745  60.586437
# 1            83.0         53.0         69.0        0.00  81.718552  58.948704
# 2            83.0         55.0         69.0        0.00  84.039566  54.553818
# 3            82.0         53.0         68.0        0.00  83.892662  55.273941
# 4            86.0         61.0         75.0        0.00  86.835060  57.691692
# ...           ...          ...          ...         ...        ...        ...
# 3564         91.0         76.0         83.0        0.00  91.073074  75.648651
# 3565         93.0         76.0         80.0        0.02  91.815102  76.093002
# 3566         93.0         73.0         83.0        0.08  91.909561  74.940910
# 3567         93.0         75.0         83.0        0.00  93.381439  74.153748
# 3568         93.0         75.0         86.0        0.00  93.332733  76.214767
#
#               2    3
# 0     71.262520  0.0
# 1     68.333557  0.0
# 2     69.844360  0.0
# 3     69.806633  0.0
# 4     72.980247  0.0
# ...         ...  ...
# 3564  81.709953  0.0
# 3565  82.903427  0.0
# 3566  80.543869  0.0
# 3567  83.020500  0.0
# 3568  83.825165  0.0
#
# [3569 rows x 8 columns]

# %%
combined.plot( )
# Out:
# <Axes: >
